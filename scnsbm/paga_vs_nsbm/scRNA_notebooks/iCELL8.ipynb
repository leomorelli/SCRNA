# %%
import scanpy as sc
import graph_tool.all as gt
import scnsbm
import pandas as pd
import anndata
import pickle
import mygene
import scipy.stats
# %pylab
# %matplotlib inline
# Out:
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# ...

# %% [markdown]
# # Equilibrate true

# %%
markers = pd.read_excel('../benchmarking_data/41587_2020_469_MOESM4_ESM.xlsx', skiprows=2)
cols = markers.columns
cols = [x.replace(' ', '_') for x in cols]
cols = [x.replace('+', '') for x in cols]
cols = [x.replace('-', '_') for x in cols]
cols = [x.replace('_cell', '') for x in cols]
markers.columns = cols

# %%
tdata = pd.read_table("../benchmarking_data/GSE133541_ICELL8_human_exp_mat.tsv.gz", compression='gzip')
adata = anndata.AnnData(tdata.T)
metadata = pd.read_table("../benchmarking_data/GSE133541_ICELL8_human_metada.tsv.gz", compression='gzip')

# %%
cells = metadata.query('nTReads > 10000 & nUnmappedReads / nTReads < 0.35').index
adata = adata[cells]
sc.pp.filter_genes(adata, min_cells=5)
# Out:
# filtered out 8209 genes that are detected in less than 5 cells
# Trying to set attribute `.var` of view, copying.

# %%
hca_annot = pd.read_table("../benchmarking_data/HCA_annotations.txt")

cells = [x for x in hca_annot.query('batch == "ICELL8"').index if x in adata.obs_names]

adata = adata[cells]

adata.obs['nnet2'] = hca_annot.loc[cells, 'nnet2']
sc.pp.filter_genes(adata, min_cells=5)
# Out:
# Trying to set attribute `.obs` of view, copying.
# filtered out 383 genes that are detected in less than 5 cells

# %%
mg = mygene.MyGeneInfo()

# %%
ensgenes = [x.split('.')[0] for x in adata.var_names]
conversion = mg.querymany(ensgenes, scopes='ensemblgene', fields='symbol', species='human', as_dataframe=True)
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-17000...done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# querying 19001-20000...done.
# querying 20001-21000...done.
# querying 21001-22000...done.
# querying 22001-23000...done.
# querying 23001-24000...done.
# querying 24001-25000...done.
# querying 25001-25679...done.
# Finished.
# 21 input query terms found dup hits:
# 	[('ENSG00000002586', 2), ('ENSG00000124333', 2), ('ENSG00000124334', 2), ('ENSG00000167393', 2), ('E
# 128 input query terms found no hit:
# ...

# %%
nv = []
for e in adata.var_names:
    k = e.split('.')[0]
    symbol = conversion.loc[k, 'symbol']
    if type(symbol) == str:
        nv.append(symbol)
    else:
        nv.append(e)
adata.var_names = nv
adata.var_names_make_unique()

# %%
mito_genes = adata.var_names.str.startswith('MT-') 
adata.obs['percent_mito'] = np.sum(adata[:, mito_genes].X, axis=1) / np.sum(adata.X, axis=1) 
adata.obs['n_counts'] = adata.X.sum(axis=1)
adata = adata[adata.obs['percent_mito'] < 0.25, :]
sc.pp.filter_cells(adata, min_genes=0)
count_thr = scipy.stats.scoreatpercentile(adata.obs['n_genes'], 95)
adata = adata[adata.obs.n_genes < count_thr, :]

sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata)
adata = adata[:, adata.var.highly_variable]
sc.pp.regress_out(adata, ['n_counts', 'percent_mito'])
sc.pp.scale(adata, max_value=10)
sc.settings.verbosity=2
# Out:
# Trying to set attribute `.obs` of view, copying.
# normalizing counts per cell
#     finished (0:00:00)
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/scanpy/preprocessing/_simple.py:297: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(data)
# extracting highly variable genes
#     finished (0:00:01)
# regressing out ['n_counts', 'percent_mito']
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/anndata/_core/anndata.py:1172: ImplicitModificationWarning: Initializing view as actual.
#   "Initializing view as actual.", ImplicitModificationWarning
# Trying to set attribute `.obs` of view, copying.
# ... storing 'nnet2' as categorical
#     finished (0:00:18)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1829 × 9081
#     obs: 'nnet2', 'percent_mito', 'n_counts', 'n_genes'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p'

# %%
sc.tl.pca(adata)
sc.pp.neighbors(adata, n_pcs=30, n_neighbors=30)
sc.tl.umap(adata)
# Out:
#     on highly variable genes
# computing PCA with n_comps = 50
#     finished (0:00:01)
# computing neighbors
#     using 'X_pca' with n_pcs = 30
#     finished (0:00:00)
# computing UMAP
#     finished (0:00:03)

# %%
sc.tl.leiden(adata)
# Out:
# running Leiden clustering
#     finished (0:00:00)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 1829 × 9081
#     obs: 'nnet2', 'percent_mito', 'n_counts', 'n_genes', 'leiden'
#     var: 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'log1p', 'pca', 'neighbors', 'umap', 'leiden'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'

# %%
scnsbm.inference.nested_model(adata, random_seed=42, equilibrate=True, steps_anneal=3)
# Out:
# minimizing the nested Stochastic Block Model
#     done (0:01:11)
# running MCMC equilibration step
#     calculating cell affinity to groups
#     finished (1:37:45)

# %%
scnsbm.io.write(adata, prefix='iCELL8')

# %%
sc.pl.umap(adata, color=["leiden",'nsbm_level_4'], legend_loc='on_data')

# %%
adata=sc.read('iCELL8.h5ad')
astate=pickle.load(open('iCELL8.pkl','rb'))

# %%
adatae.write('state_adata/iCELL8_equilibrate.h5ad')
pickle.dump(astate,open('state_adata/iCELL8_equilibrate.pkl','wb'),2)
# Out:
# ... storing 'nnet2' as categorical

# %%
adatae=sc.read('state_adata/iCELL8_equilibrate.h5ad')
estate=pickle.load(open('state_adata/iCELL8_equilibrate.pkl','rb'))

# %% [markdown]
# # Equilibrate false

# %%
scnsbm.inference.nested_model(adata, random_seed=42, equilibrate=False, steps_anneal=3, n_init=3)
# Out:
# minimizing the nested Stochastic Block Model
#     done (0:03:18)
#     calculating cell affinity to groups
#     finished (0:03:23)

# %%
scnsbm.io.write(adata, prefix='iCELL8')

# %%
adata=sc.read('iCELL8.h5ad')
astate=pickle.load(open('iCELL8.pkl','rb'))

# %%
adata.write('state_adata/iCELL8_minimize.h5ad')
pickle.dump(astate,open('state_adata/iCELL8_minimize.pkl','wb'),2)

# %%
adatam=sc.read('state_adata/iCELL8_minimize.h5ad')
mstate=pickle.load(open('state_adata/iCELL8_minimize.pkl','rb'))

# %%
sc.pl.umap(adatae, color=["leiden",'nnet2','nsbm_level_3'], legend_loc='on_data')

# %%
sc.pl.umap(adatam, color=["leiden",'nnet2','nsbm_level_2'], legend_loc='on_data')

# %% [markdown]
# # PAGA

# %%
print('paga leiden')
sc.tl.paga(adatae,groups='leiden')
sc.pl.paga(adatae, color=['leiden'])
print('paga nsbm')
sc.tl.paga(adatae,groups='nsbm_level_3')
sc.pl.paga(adatae, color=['nsbm_level_3'])
# Out:
# paga leiden
# paga nsbm

# %%
print('paga leiden')
sc.tl.paga(adatam,groups='leiden')
sc.pl.paga(adatam, color=['leiden'])
print('paga nsbm')
sc.tl.paga(adatam,groups='nsbm_level_3')
sc.pl.paga(adatam, color=['nsbm_level_3'])
print('paga nnet2')
sc.tl.paga(adatam,groups='nnet2')
sc.pl.paga(adatam, color=['nnet2'])
# Out:
# paga leiden
# paga nsbm
# paga nnet2

# %%
adatam.write('state_adata/iCELL8_minimize.h5ad')
adatae.write('state_adata/iCELL8_equilibrate.h5ad')

# %%
adatam=sc.read('state_adata/iCELL8_minimize.h5ad')
adatae=sc.read('state_adata/iCELL8_equilibrate.h5ad')

# %%
sc.tl.paga(adatam,groups='nnet2')
sc.tl.draw_graph(adatam, init_pos='paga')
sc.pl.draw_graph(adatam, color=['leiden', 'nnet2', 'nsbm_level_3'], legend_loc='on data')
# Out:
# running PAGA
#     finished (0:00:00)
# drawing single-cell graph using layout 'fa'
# WARNING: Package 'fa2' is not installed, falling back to layout 'fr'.To use the faster and better ForceAtlas2 layout, install package 'fa2' (`pip install fa2`).
#     finished (0:00:06)

# %%
print('paga leiden')
sc.tl.paga(adatae,groups='leiden')
sc.pl.paga(adatae, color=['leiden'])
print('paga nsbm')
sc.tl.paga(adatae,groups='nsbm_level_3')
sc.pl.paga(adatae, color=['nsbm_level_3'])
print('paga nnet2')
sc.tl.paga(adatae,groups='nnet2')
sc.pl.paga(adatae, color=['nnet2'])
# Out:
# paga leiden
# running PAGA
#     finished (0:00:00)
# paga nsbm
# running PAGA
#     finished (0:00:00)
# paga nnet2
# running PAGA
#     finished (0:00:00)

# %%
sc.tl.paga(adatae,groups='nnet2')
sc.tl.draw_graph(adatae, init_pos='paga')
sc.pl.draw_graph(adatae, color=['leiden', 'nnet2', 'nsbm_level_3'], legend_loc='on data')
# Out:
# running PAGA
#     finished (0:00:00)
# drawing single-cell graph using layout 'fa'
# WARNING: Package 'fa2' is not installed, falling back to layout 'fr'.To use the faster and better ForceAtlas2 layout, install package 'fa2' (`pip install fa2`).
#     finished (0:00:05)

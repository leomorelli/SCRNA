# %%
import scanpy as sc
import graph_tool.all as gt
import scnsbm
import pandas as pd
import anndata
import pickle
import mygene
import scipy.stats
# %pylab
# %matplotlib inline
# Out:
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /home/morelli/anaconda3/envs/scrna/lib/python3.7/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# ...

# %% [markdown]
# # mixology10x

# %%
adatae_10x=sc.read('../scRNA_paga/state_adata/mixology10x_equilibrate.h5ad')
adatam_10x=sc.read('../scRNA_paga/state_adata/mixology10x_minimize.h5ad')

# %%
M=adatam_10x.uns['nsbm']['cell_affinity']['2']
adatam_10x.obs['max_u'] = 1 - np.max(M, axis=1) 
sc.pl.umap(adatam_10x[adatam_10x.obs.max_u < 1e-100], color=['nsbm_level_2','cell_line'])
# Out:
# Trying to set attribute `.uns` of view, copying.

# %%
M=adatae_10x.uns['nsbm']['cell_affinity']['2']
adatae_10x.obs['max_u'] = 1 - np.max(M, axis=1) 
sc.pl.umap(adatae_10x[adatae_10x.obs.max_u < 1e-100], color=['nsbm_level_2','cell_line'])
# Out:
# Trying to set attribute `.uns` of view, copying.

# %%
ciao3=adatam_10x[adatam_10x.obs.max_u < 1e-100]

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
sc.tl.rank_genes_groups(ciao3, groupby='nsbm_level_2', method='logreg',max_iter=500)
# Out:
# Trying to set attribute `.uns` of view, copying.

# %%
for x in ciao3.uns['rank_genes_groups']['names']['1']:
    print(x)
# Out:
# DHRS2
# LGALS1
# MT1E
# XAGE1B
# SNHG5
# PRDX2
# PEG10
# HSPB1
# VIM
# TNNT1
# SELENOM
# UQCR10
# IFITM3
# GPX4
# C19orf70
# CT45A2
# AKR1B1
# RPS28P7
# RPS15
# UBE2S
# AC007969.1
# TIMP1
# ELP5
# RPL28
# UQCR11
# UBE2SP1
# MT2A
# XAGE1A
# TMEM134
# RPS5
# MRPL11
# CAV1
# NDUFA3
# FKBP1A
# MGP
# PLTP
# ZNF880
# BST2
# RPL36
# GADD45GIP1
# NEAT1
# SNU13
# IFI27
# PPP1CA
# TOMM7
# OST4
# NDUFV1
# ACTN1
# ACTB
# CHMP2A
# AC107983.1
# HSPB1P1
# TGFBI
# LAGE3
# UPP1
# FIS1
# PPP2R1A
# LSM7
# SNRPN
# H2AFJ
# SERPINH1
# CT45A9
# TUBA1A
# DMKN
# CDK2AP2
# SRI
# CST3
# TMEM256
# C20orf27
# VCAN
# IGFBP6
# ISG15
# OAZ1
# BSG
# PRSS23
# RPL29P11
# METRN
# SAT2
# RPL26P19
# AP3S1
# GPX1
# NDUFA6
# CALD1
# PVT1
# YWHAH
# DHRS7
# C19orf24
# CAVIN3
# TMSB4X
# S100A2
# HIST1H1C
# PRPF31
# MT1P1
# GSTO2
# NAA38
# STMP1
# C7orf50
# TNNI3
# AL669983.1
# ASNA1

# %% [markdown]
# # mixology dropseq

# %%
adatae_dropseq=sc.read('../scRNA_paga/state_adata/mixology_dropseq_equilibrate.h5ad')
adatam_dropseq=sc.read('../scRNA_paga/state_adata/mixology_dropseq_minimize.h5ad')

# %%
M=adatam_dropseq.uns['nsbm']['cell_affinity']['1']
adatam_dropseq.obs['max_u'] = 1 - np.max(M, axis=1) 
sc.pl.umap(adatam_dropseq[adatam_dropseq.obs.max_u < 1e-10], color=['nsbm_level_1','cell_line'])
# Out:
# Trying to set attribute `.uns` of view, copying.

# %%
M=adatae_dropseq.uns['nsbm']['cell_affinity']['1']
adatae_dropseq.obs['max_u'] = 1 - np.max(M, axis=1) 
sc.pl.umap(adatae_dropseq[adatae_dropseq.obs.max_u < 1e-10], color=['nsbm_level_1','cell_line'])
# Out:
# Trying to set attribute `.uns` of view, copying.

# %% [markdown]
# # PBMC

# %%
adatae_pbmc=sc.read('../scRNA_paga/state_adata/pbmc_equilibrate.h5ad')
adatam_pbmc=sc.read('../scRNA_paga/state_adata/pbmc_minimize.h5ad')

# %%
M=adatam_pbmc.uns['nsbm']['cell_affinity']['1']
adatam_pbmc.obs['max_u'] = 1 - np.max(M, axis=1) 
sc.pl.umap(adatam_pbmc[adatam_pbmc.obs.max_u < 1e-10], color=['nsbm_level_2','leiden'])
# Out:
# Trying to set attribute `.uns` of view, copying.

# %%
ciao3=adatam_pbmc[adatam_pbmc.obs.max_u < 1e-10]

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
sc.tl.rank_genes_groups(ciao3, groupby='nsbm_level_2', method='logreg',max_iter=500)
# Out:
# Trying to set attribute `.uns` of view, copying.

# %%
for x in ciao3.uns['rank_genes_groups']['names']['7']:
    print(x)
# Out:
# PPBP
# PF4
# SDPR
# HIST1H2AC
# FCGR3A
# NAP1L1
# GNG11
# RGS18
# CEBPB
# STXBP2
# RHOC
# GNAS
# SAT1
# DYNLL1
# ILK
# CLU
# TIMP1
# TSC22D1
# RAP1B
# RP11-290F20.3
# MS4A7
# NGFRAP1
# SPARC
# COTL1
# GP9
# PSAP
# NRGN
# CNIH4
# ITM2B
# CDKN2D
# CALM3
# LST1
# HIST1H2BK
# SH3BGRL
# TUBB1
# C5AR1
# TAGLN2
# AIF1
# HSBP1
# MT-ATP6
# RGS10
# TPPP3
# PGRMC1
# GPX1
# FTH1
# YPEL5
# SLC11A1
# PMVK
# MRPS7
# PILRA
# ACRBP
# OAZ1
# PPDPF
# CA2
# PTPN18
# ARPC1B
# FTL
# MYL12A
# H3F3A
# MT-ND2
# RBX1
# GRAP2
# PTCRA
# MYL6
# FLNA
# CUX1
# RUFY1
# AP001189.4
# FERMT3
# ACTB
# GNAI2
# C11orf31
# ICAM2
# CCL5
# BRI3
# NCOA4
# AKIRIN2
# FCER1G
# MVP
# CRIP1
# PKM
# ITGA2B
# PRDX6
# HIST2H2BE
# ADA
# RBM4
# SNAP23
# SERP1
# MT-CO2
# YWHAH
# HSP90AA1
# EVI2B
# LEPROT
# TREML1
# DECR1
# LTA4H
# ASAH1
# FAM26F
# RNF144B
# ARHGEF1

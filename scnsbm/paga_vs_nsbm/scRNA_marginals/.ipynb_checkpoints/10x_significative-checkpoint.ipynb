# %%
import scanpy as sc
import graph_tool.all as gt
import schist
import pandas as pd
import anndata
import pickle
import mygene
import scipy.stats
import statsmodels.api as sm
# %pylab
# %matplotlib inline
# Out:
# /home/morelli/anaconda3/envs/SCRNA/lib/python3.8/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex
# /home/morelli/anaconda3/envs/SCRNA/lib/python3.8/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /home/morelli/anaconda3/envs/SCRNA/lib/python3.8/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /home/morelli/anaconda3/envs/SCRNA/lib/python3.8/site-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# ...

# %%
adata=schist.io.read('../scRNA_paga/state_adata/10XV3_minimize')
minimize_linear_weighted=pickle.load(open('cell_affinity_significance/minimize_linear_weighted_weighted_adatam_10X.pkl','rb'))
minimize_linear_flat=pickle.load(open('cell_affinity_significance/minimize_linear_flat_weighted_adatam_10X.pkl','rb'))

# %%
#denoised weighted nSBM
adata=schist.io.read('../scRNA_paga/state_adata/10XV3_minimize_denoised_weighted')
w_pvals_l4=pickle.load(open('cell_affinity_significance/dw10XV3_weighted_level_4_pvals.pkl','rb'))
w_padj_l4=pickle.load(open('cell_affinity_significance/dw10XV3_weighted_level_4_pvals_adj.pkl','rb'))
w_pvals_l2=pickle.load(open('cell_affinity_significance/dw10XV3_weighted_level_2_pvals.pkl','rb'))
w_padj_l2=pickle.load(open('cell_affinity_significance/dw10XV3_weighted_level_2_pvals_adj.pkl','rb'))
w_pvals_l3=pickle.load(open('cell_affinity_significance/dw10XV3_weighted_level_3_pvals.pkl','rb'))
w_padj_l3=pickle.load(open('cell_affinity_significance/dw10XV3_weighted_level_3_pvals_adj.pkl','rb'))
f_pvals_l4=pickle.load(open('cell_affinity_significance/dw10XV3_flat_level_4_pvals.pkl','rb'))
f_padj_l4=pickle.load(open('cell_affinity_significance/dw10XV3_flat_level_4_pvals_adj.pkl','rb'))
f_pvals_l2=pickle.load(open('cell_affinity_significance/dw10XV3_flat_level_2_pvals.pkl','rb'))
f_padj_l2=pickle.load(open('cell_affinity_significance/dw10XV3_flat_level_2_pvals_adj.pkl','rb'))
f_pvals_l3=pickle.load(open('cell_affinity_significance/dw10XV3_flat_level_3_pvals.pkl','rb'))
f_padj_l3=pickle.load(open('cell_affinity_significance/dw10XV3_flat_level_3_pvals_adj.pkl','rb'))

# %%
#denoised unweighted nSBM
adata=schist.io.read('../scRNA_paga/state_adata/10XV3_minimize_denoised')
w_pvals_l4=pickle.load(open('cell_affinity_significance/d10XV3_weighted_level_4_pvals.pkl','rb'))
w_padj_l4=pickle.load(open('cell_affinity_significance/d10XV3_weighted_level_4_pvals_adj.pkl','rb'))
w_pvals_l2=pickle.load(open('cell_affinity_significance/d10XV3_weighted_level_2_pvals.pkl','rb'))
w_padj_l2=pickle.load(open('cell_affinity_significance/d10XV3_weighted_level_2_pvals_adj.pkl','rb'))
w_pvals_l3=pickle.load(open('cell_affinity_significance/d10XV3_weighted_level_3_pvals.pkl','rb'))
w_padj_l3=pickle.load(open('cell_affinity_significance/d10XV3_weighted_level_3_pvals_adj.pkl','rb'))
f_pvals_l4=pickle.load(open('cell_affinity_significance/d10XV3_flat_level_4_pvals.pkl','rb'))
f_padj_l4=pickle.load(open('cell_affinity_significance/d10XV3_flat_level_4_pvals_adj.pkl','rb'))
f_pvals_l2=pickle.load(open('cell_affinity_significance/d10XV3_flat_level_2_pvals.pkl','rb'))
f_padj_l2=pickle.load(open('cell_affinity_significance/d10XV3_flat_level_2_pvals_adj.pkl','rb'))
f_pvals_l3=pickle.load(open('cell_affinity_significance/d10XV3_flat_level_3_pvals.pkl','rb'))
f_padj_l3=pickle.load(open('cell_affinity_significance/d10XV3_flat_level_3_pvals_adj.pkl','rb'))

# %%
#weighted nSBM
adata=schist.io.read('../scRNA_paga/state_adata/10XV3_minimize_weighted')
w_pvals_l1=pickle.load(open('cell_affinity_significance/w10XV3_weighted_level_1_pvals.pkl','rb'))
w_padj_l1=pickle.load(open('cell_affinity_significance/w10XV3_weighted_level_1_pvals_adj.pkl','rb'))
w_pvals_l2=pickle.load(open('cell_affinity_significance/w10XV3_weighted_level_2_pvals.pkl','rb'))
w_padj_l2=pickle.load(open('cell_affinity_significance/w10XV3_weighted_level_2_pvals_adj.pkl','rb'))
w_pvals_l3=pickle.load(open('cell_affinity_significance/w10XV3_weighted_level_3_pvals.pkl','rb'))
w_padj_l3=pickle.load(open('cell_affinity_significance/w10XV3_weighted_level_3_pvals_adj.pkl','rb'))
f_pvals_l1=pickle.load(open('cell_affinity_significance/w10XV3_flat_level_1_pvals.pkl','rb'))
f_padj_l1=pickle.load(open('cell_affinity_significance/w10XV3_flat_level_1_pvals_adj.pkl','rb'))
f_pvals_l2=pickle.load(open('cell_affinity_significance/w10XV3_flat_level_2_pvals.pkl','rb'))
f_padj_l2=pickle.load(open('cell_affinity_significance/w10XV3_flat_level_2_pvals_adj.pkl','rb'))
f_pvals_l3=pickle.load(open('cell_affinity_significance/w10XV3_flat_level_3_pvals.pkl','rb'))
f_padj_l3=pickle.load(open('cell_affinity_significance/w10XV3_flat_level_3_pvals_adj.pkl','rb'))

# %%
#unweighted nSBM
adata=schist.io.read('../scRNA_paga/state_adata/10XV3_minimize')
w_pvals_l1=pickle.load(open('cell_affinity_significance/10XV3_weighted_level_1_pvals.pkl','rb'))
w_padj_l1=pickle.load(open('cell_affinity_significance/10XV3_weighted_level_1_pvals_adj.pkl','rb'))
w_pvals_l2=pickle.load(open('cell_affinity_significance/10XV3_weighted_level_2_pvals.pkl','rb'))
w_padj_l2=pickle.load(open('cell_affinity_significance/10XV3_weighted_level_2_pvals_adj.pkl','rb'))
w_pvals_l3=pickle.load(open('cell_affinity_significance/10XV3_weighted_level_3_pvals.pkl','rb'))
w_padj_l3=pickle.load(open('cell_affinity_significance/10XV3_weighted_level_3_pvals_adj.pkl','rb'))
f_pvals_l1=pickle.load(open('cell_affinity_significance/10XV3_flat_level_1_pvals.pkl','rb'))
f_padj_l1=pickle.load(open('cell_affinity_significance/10xV3_flat_level_1_pvals_adj.pkl','rb'))
f_pvals_l2=pickle.load(open('cell_affinity_significance/10XV3_flat_level_2_pvals.pkl','rb'))
f_padj_l2=pickle.load(open('cell_affinity_significance/10xV3_flat_level_2_pvals_adj.pkl','rb'))
f_pvals_l3=pickle.load(open('cell_affinity_significance/10XV3_flat_level_3_pvals.pkl','rb'))
f_padj_l3=pickle.load(open('cell_affinity_significance/10xV3_flat_level_3_pvals_adj.pkl','rb'))

# %%
markers=pd.read_excel("markers_hca.ods", engine="odf",header=2,index_col=None)

# %%
sc.pl.umap(adata,color=['nsbm_level_2','nnet2'],legend_loc ='on data')

# %%
significative=0    
for group in adata.obs.nsbm_level_2.cat.categories:
    sig_level=len([x for x in f_pvals_l2[:,int(group)] if x <0.05])
    significative=significative+sig_level
print(significative)
# Out:
# 25663

# %% [markdown]
# # 1) Number of genes
# In order to assess the validity of cells-weigths calculated by nSBM model. We firstly compared the the amount of significative genes found by regular flat analysis to the number of significative genes gained through the analysis affected by cells-weights. The more succesfull and effecctive is the analysis, the higher is the number of significative genes.

# %% [markdown]
# ### flat model

# %%
hist(un_f_pvals_l2[:,1],bins=np.linspace(0,1,20))
# Out:
# (array([1313.,  391.,  330.,  308.,  308.,  224.,  245.,  237.,  205.,
#          208.,  224.,  183.,  189.,  211.,  186.,  197.,  169.,  201.,
#          188.]),
#  array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#         0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#         0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#         0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ]),
#  <a list of 19 Patch objects>)

# %%
significative=0
for group in adata.obs.nsbm_level_2.cat.categories:
    sig_level=len([x for x in un_f_pvals_l2[:,int(group)] if x <0.05])
    significative=significative+sig_level
print(significative)
# Out:
# 18190

# %% [markdown]
# ### weighted model

# %%
hist(w_pvals_l2[:,8],bins=np.linspace(0,1,20))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-074d38ba907f> in <module>
# ----> 1 hist(w_pvals_l2[:,8],bins=np.linspace(0,1,20))
#
# IndexError: index 8 is out of bounds for axis 1 with size 2

# %%
significative=0
for group in adata.obs.nsbm_level_2.cat.categories:
    sig_level=len([x for x in un_w_pvals_l2[:,int(group)] if x <0.05])
    significative=significative+sig_level
print(significative)
# Out:
# 18089

# %% [markdown]
# ### scanpy

# %%
sc.tl.rank_genes_groups(adatam,groupby='nsbm_level_2',n_genes=-1)
# Out:
# /home/morelli/anaconda3/envs/SCRNA/lib/python3.8/site-packages/scanpy/tools/_rank_genes_groups.py:252: RuntimeWarning: invalid value encountered in log2
#   rankings_gene_logfoldchanges.append(np.log2(foldchanges[global_indices]))

# %%
hist([adatam.uns['rank_genes_groups']['pvals_adj'][x][9] for x in range(5516)],bins=np.linspace(0,1,20))
# Out:
# (array([6.000e+00, 1.000e+00, 3.000e+00, 5.000e+00, 4.000e+00, 2.000e+00,
#         7.000e+00, 0.000e+00, 5.000e+00, 7.000e+00, 6.000e+00, 3.000e+00,
#         0.000e+00, 4.000e+00, 1.600e+01, 1.500e+01, 7.000e+00, 2.900e+01,
#         5.396e+03]),
#  array([0.        , 0.05263158, 0.10526316, 0.15789474, 0.21052632,
#         0.26315789, 0.31578947, 0.36842105, 0.42105263, 0.47368421,
#         0.52631579, 0.57894737, 0.63157895, 0.68421053, 0.73684211,
#         0.78947368, 0.84210526, 0.89473684, 0.94736842, 1.        ]),
#  <a list of 19 Patch objects>)

# %% [markdown]
# scanpy tool performs worse than our tool
# ### conclusions
# The main information we achieved is that there is not a huge difference between weighted model and flat model in terms of number of significative genes, but usually the weighted model increase the number of genes with significative p-values

# %% [markdown]
# # 2) Markers
# Our second approach was focused on finding the concordance between marker-genes of each cell-type in the sample and the 100 most significative genes of each group found by nSBM. After that, the performance of the weighted model was compered to the performance of the flat model

# %%
sc.pl.umap(adata, color=['nsbm_level_2','nnet2'],legend_loc='on data')
pd.crosstab(adata.obs['nsbm_level_2'],adata.obs['nnet2'])
# Out:
# nnet2         B cells  CD4 T cells  CD8 T cells  CD14+ Monocytes  \
# nsbm_level_2
# 0                  88           81           10                0
# 1                   0           76            0                0
# 2                   0           14            3                0
# 3                   0          107            0                0
# 4                   0           26            0                0
# 5                   0            2            0                0
# 6                   0            0            0               26
# 7                   0            0           14                0
# 8                   0            0           24                0
# 9                  14           27           10                0
# 10                  0            7            0                0
# 11                  0            0            0               96
# 12                  0            0            5                0
# ...

# %%
for celltype in range(len(markers.columns)):
    wm=[]
    fm=[]
    flat=0
    weight=0
    gene=[str(i) for i in markers.iloc[:,celltype]]
    for i in adatam.obs['nsbm_level_1'].cat.categories:
        for j in minimize_linear_flat['e0'][i]['gene_names'][:100]:
            if j in gene:
                flat=flat+1
        fm.append(flat)
        flat=0
        for s in minimize_linear_weighted[i]['gene_names'][:100]:
#        for s in minimize_linear_flat['e-10'][i]['gene_names'][:100]:
            if s in gene:
                weight=weight+1
        wm.append(weight)
        weight=0
    figure()
    title(f'{markers.columns[celltype]}')
    plot(fm)
    plot(wm)

# %% [markdown]
# Also in this case there are few differences between the two models, but weighted model is still sligthly better than flat model:
#
#
#
#
#    1) Hek cells for example are present also in group 3 and 16 and weighted model shows higher number of matched genes for these two groups with HEK markers
#
#
#
#    2) 15/20 of dendritic cells are located in groupp 14 and also in this case, the weighted model showed an higher concordance with marker genes

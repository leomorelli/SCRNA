# %%
import scanpy as sc
import pandas as pd
import pickle
import numpy as np
import graph_tool.all as gt
import anndata
import time
# %matplotlib inline
# %pylab
# Out:
# /usr/lib/python3/dist-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /usr/lib/python3/dist-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /usr/lib/python3/dist-packages/graph_tool/draw/cairo_draw.py:39: RuntimeWarning: Error importing cairo. Graph drawing will not work.
#   warnings.warn(msg, RuntimeWarning)
# /usr/lib/python3/dist-packages/graph_tool/all.py:40: RuntimeWarning: Error importing draw module, proceeding nevertheless: /usr/lib/python3/dist-packages/cairo/_cairo.cpython-37m-x86_64-linux-gnu.so: undefined symbol: cairo_tee_surface_index
#   warnings.warn(msg, RuntimeWarning)
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
adata=sc.read('pbmc/adata_sc_pbmc.h5ad')

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')
df_significativo= pd.DataFrame(adata.uns['rank_genes_groups']['names']).head(20) #### df con i 20 geni significativi per gruppo

# %%
g = pickle.load( open( "pbmc/pbmc_g.pkl", "rb" ))

# %% [markdown]
# # 1) minimize+sweep
# ### 1a) timing (a:406 sec)(b:366 sec)(c:375 sec)(d:381 sec)(e:412 sec) (circa 6 minuti e 30 sec)

# %%
a=time.time()
state=gt.minimize_nested_blockmodel_dl(g, deg_corr=False, mcmc_args=dict(niter=1000))
b=time.time()
c=b-a
print(c)
pickle.dump(state,open("pbmc/pbmc_reliability_test/state_a.pkl",'wb'),2)
state
# Out:
# 406.60366225242615
# <NestedBlockState object, with base <BlockState object with 55 blocks (55 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1549f0d0>, at 0x7fea153fbc90>, and 5 levels of sizes [(2638, 55), (55, 11), (11, 4), (4, 2), (2, 1)] at 0x7fea2c9741d0>

# %%
state_a=pickle.load( open( "pbmc/pbmc_reliability_test/state_a.pkl", "rb" ))

# %%
a=time.time()
state=gt.minimize_nested_blockmodel_dl(g, deg_corr=False, mcmc_args=dict(niter=1000))
b=time.time()
c=b-a
print(c)
pickle.dump(state,open("pbmc/pbmc_reliability_test/state_b.pkl",'wb'),2)
state
# Out:
# 366.61635303497314
# <NestedBlockState object, with base <BlockState object with 66 blocks (66 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1549f0d0>, at 0x7fea15408b90>, and 5 levels of sizes [(2638, 66), (66, 16), (16, 7), (7, 2), (2, 1)] at 0x7fea153fc350>

# %%
state_b=pickle.load( open( "pbmc/pbmc_reliability_test/state_b.pkl", "rb" ))

# %%
a=time.time()
state=gt.minimize_nested_blockmodel_dl(g, deg_corr=False, mcmc_args=dict(niter=1000))
b=time.time()
c=b-a
print(c)
pickle.dump(state,open("pbmc/pbmc_reliability_test/state_c.pkl",'wb'),2)
state
# Out:
# 375.2826614379883
# <NestedBlockState object, with base <BlockState object with 79 blocks (79 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1549f0d0>, at 0x7fea15374110>, and 5 levels of sizes [(2638, 79), (79, 13), (13, 5), (5, 2), (2, 1)] at 0x7fea15416450>

# %%
state_c=pickle.load( open( "pbmc/pbmc_reliability_test/state_c.pkl", "rb" ))

# %%
a=time.time()
state=gt.minimize_nested_blockmodel_dl(g, deg_corr=False, mcmc_args=dict(niter=1000))
b=time.time()
c=b-a
print(c)
pickle.dump(state,open("pbmc/pbmc_reliability_test/state_d.pkl",'wb'),2)
state
# Out:
# 381.5356695652008
# <NestedBlockState object, with base <BlockState object with 52 blocks (52 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1549f0d0>, at 0x7fea15416490>, and 5 levels of sizes [(2638, 52), (52, 16), (16, 5), (5, 2), (2, 1)] at 0x7fea1537de10>

# %%
state_d=pickle.load( open( "pbmc/pbmc_reliability_test/state_d.pkl", "rb" ))

# %%
a=time.time()
state=gt.minimize_nested_blockmodel_dl(g, deg_corr=False, mcmc_args=dict(niter=1000))
b=time.time()
c=b-a
print(c)
pickle.dump(state,open("pbmc/pbmc_reliability_test/state_e.pkl",'wb'),2)
state
# Out:
# 412.4864115715027
# <NestedBlockState object, with base <BlockState object with 86 blocks (86 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1549f0d0>, at 0x7fea15313bd0>, and 5 levels of sizes [(2638, 86), (86, 15), (15, 6), (6, 2), (2, 1)] at 0x7fea153f2690>

# %%
state_e=pickle.load( open( "pbmc/pbmc_reliability_test/state_e.pkl", "rb" ))

# %% [markdown]
# ### 1b) reppresentation

# %%
#state_a
adata.obs.loc[:, 'NSBM_test'] = pd.Categorical(list(state_a.project_level(2).get_blocks()))
sc.pl.umap(adata, color=["NSBM_test", 'leiden'], legend_loc='on data')
print(pd.crosstab(adata.obs.NSBM_test, adata.obs.leiden))
# Out:
# leiden        0    1    2    3    4    5   6   7
# NSBM_test
# 0          1109    0    1   22    0    1   0   0
# 1             0    0  340    0    0    0   0   0
# 2             0  486    0    0    0  148  36  13
# 3            34    0    0  284  163    1   0   0

# %%
#state_b
adata.obs.loc[:, 'NSBM_test'] = pd.Categorical(list(state_b.project_level(2).get_blocks()))
sc.pl.umap(adata, color=["NSBM_test", 'leiden'], legend_loc='on data')
print(pd.crosstab(adata.obs.NSBM_test, adata.obs.leiden))
# Out:
# leiden       0    1    2    3    4    5   6   7
# NSBM_test
# 0          389    0    0    4    0    0   0   0
# 1            0    0  339    0    0    0   0   0
# 2          333    0    2    4    0    2   0   0
# 3            0  483    0    0    0  148   0  13
# 4            2    0    0  243  163    0   0   0
# 5          419    0    0   55    0    0   0   0
# 6            0    3    0    0    0    0  36   0

# %%
#state_c
adata.obs.loc[:, 'NSBM_test'] = pd.Categorical(list(state_c.project_level(2).get_blocks()))
sc.pl.umap(adata, color=["NSBM_test", 'leiden'], legend_loc='on data')
print(pd.crosstab(adata.obs.NSBM_test, adata.obs.leiden))
# Out:
# leiden        0    1    2    3    4    5   6   7
# NSBM_test
# 0          1139    0    0   61    0    2   0   0
# 1             0    0  341    0    0    0   0   0
# 2             0  440    0    0    0   31  36   0
# 3             4    0    0  245  163    1   0  13
# 4             0   46    0    0    0  116   0   0

# %%
#state_d
adata.obs.loc[:, 'NSBM_test'] = pd.Categorical(list(state_d.project_level(2).get_blocks()))
sc.pl.umap(adata, color=["NSBM_test", 'leiden'], legend_loc='on data')
print(pd.crosstab(adata.obs.NSBM_test, adata.obs.leiden))
# Out:
# leiden        0    1    2    3    4    5   6   7
# NSBM_test
# 0          1137    0    1   42    0    1   0   0
# 1             0    0  340    0    0    0   0   0
# 2             0  478    0    0    0  146   0   0
# 3             6    0    0  264  163    0   0   0
# 4             0    8    0    0    0    3  36  13

# %%
#state_e
adata.obs.loc[:, 'NSBM_test'] = pd.Categorical(list(state_e.project_level(2).get_blocks()))
sc.pl.umap(adata, color=["NSBM_test", 'leiden'], legend_loc='on data')
print(pd.crosstab(adata.obs.NSBM_test, adata.obs.leiden))
# Out:
# leiden        0    1    2    3    4   5   6   7
# NSBM_test
# 0          1078    0    2   22    0   0   0   0
# 1             0    0  339    0    0   0   0   0
# 2             0  457    0    0    0  83   0   0
# 3            11    0    0  249  163   0   0   0
# 4            54    0    0   35    0   2   0   0
# 5             0   29    0    0    0  65  36  13

# %% [markdown]
# # 2) equilibrate: w=1000, nbreaks=2, epsilon=0.001
# ### 2a) Timing
# ##### 2aa)  state_a  (517 sec)(724 sec)(610 sec) (circa 10 min e venti sec)

# %%
bs = state_a.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_a.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_a.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_a.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_a2.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_a2.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_a2.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 517.034018278122
# <NestedBlockState object, with base <BlockState object with 67 blocks (65 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea153f6950>, at 0x7fea16860f90>, and 10 levels of sizes [(2638, 65), (65, 17), (17, 8), (8, 7), (7, 5), (5, 4), (4, 3), (3, 2), (2, 2), (2, 2)] at 0x7fea16860fd0>

# %%
bs = state_a.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_a.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_a.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_a.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_a3.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_a3.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_a3.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 724.5837769508362
# <NestedBlockState object, with base <BlockState object with 67 blocks (64 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea153f6950>, at 0x7fea168626d0>, and 10 levels of sizes [(2638, 64), (64, 18), (18, 8), (8, 6), (6, 5), (5, 5), (5, 4), (4, 3), (3, 2), (2, 2)] at 0x7fea167af250>

# %%
bs = state_a.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_a.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_a.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_a.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_a1.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_a1.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_a1.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 610.1624693870544
# <NestedBlockState object, with base <BlockState object with 69 blocks (67 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea153f6950>, at 0x7fea167afa10>, and 10 levels of sizes [(2638, 67), (67, 20), (20, 8), (8, 6), (6, 4), (4, 3), (3, 3), (3, 2), (2, 2), (2, 2)] at 0x7fea167afb50>

# %%
estate_a1=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_a1.pkl", "rb" ))
estate_a2=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_a2.pkl", "rb" ))
estate_a3=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_a3.pkl", "rb" ))

# %% [markdown]
# ##### 2ab)  state_b (634)(551)(367) (circa 8 min e 40 sec)

# %%
bs = state_b.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_b.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_b.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_b.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_b1.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_b1.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_b1.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 634.9620826244354
# <NestedBlockState object, with base <BlockState object with 81 blocks (79 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea152f3090>, at 0x7fea15662cd0>, and 10 levels of sizes [(2638, 79), (79, 19), (19, 9), (9, 6), (6, 4), (4, 3), (3, 3), (3, 3), (3, 2), (2, 2)] at 0x7fea15662510>

# %%
bs = state_b.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_b.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_b.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_b.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_b2.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_b2.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_b2.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 551.8022263050079
# <NestedBlockState object, with base <BlockState object with 77 blocks (76 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea152f3090>, at 0x7fea155fd450>, and 10 levels of sizes [(2638, 76), (76, 19), (19, 11), (11, 6), (6, 4), (4, 4), (4, 4), (4, 3), (3, 2), (2, 2)] at 0x7fea155fd110>

# %%
bs = state_b.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_b.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_b.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_b.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_b3.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_b3.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_b3.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 367.5440649986267
# <NestedBlockState object, with base <BlockState object with 73 blocks (71 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea152f3090>, at 0x7fea1558e4d0>, and 10 levels of sizes [(2638, 71), (71, 20), (20, 9), (9, 5), (5, 3), (3, 2), (2, 2), (2, 2), (2, 2), (2, 1)] at 0x7fea15662550>

# %%
estate_b1=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_b1.pkl", "rb" ))
estate_b2=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_b2.pkl", "rb" ))
estate_b3=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_b3.pkl", "rb" ))

# %% [markdown]
# ##### 2ac)  state_c (516)(483)(676) (circa 9.20 min)

# %%
bs = state_c.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_c.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_c.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_c.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_c1.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_c1.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_c1.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 516.4176681041718
# <NestedBlockState object, with base <BlockState object with 88 blocks (87 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1540aed0>, at 0x7fea16882150>, and 10 levels of sizes [(2638, 87), (87, 19), (19, 9), (9, 5), (5, 3), (3, 3), (3, 3), (3, 2), (2, 2), (2, 2)] at 0x7fea168826d0>

# %%
bs = state_c.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_c.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_c.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_c.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_c2.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_c2.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_c2.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 483.4439730644226
# <NestedBlockState object, with base <BlockState object with 84 blocks (82 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1540aed0>, at 0x7fea1567b510>, and 10 levels of sizes [(2638, 82), (82, 20), (20, 8), (8, 6), (6, 5), (5, 4), (4, 4), (4, 4), (4, 3), (3, 2)] at 0x7fea10301310>

# %%
bs = state_c.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_c.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_c.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_c.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_c3.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_c3.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_c3.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 675.9977707862854
# <NestedBlockState object, with base <BlockState object with 85 blocks (83 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1540aed0>, at 0x7fea1555ec90>, and 10 levels of sizes [(2638, 83), (83, 21), (21, 10), (10, 5), (5, 4), (4, 3), (3, 3), (3, 3), (3, 3), (3, 2)] at 0x7fea15354d90>

# %%
estate_c1=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_c1.pkl", "rb" ))
estate_c2=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_c2.pkl", "rb" ))
estate_c3=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_c3.pkl", "rb" ))

# %% [markdown]
# ##### 2ad)  state_d (383)(491)(692) (8 min e 40 sec)

# %%
bs = state_d.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_d.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_d.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_d.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_d1.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_d1.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_d1.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 383.70038175582886
# <NestedBlockState object, with base <BlockState object with 60 blocks (58 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea166dd050>, at 0x7fea152a9090>, and 10 levels of sizes [(2638, 58), (58, 18), (18, 8), (8, 5), (5, 5), (5, 4), (4, 2), (2, 2), (2, 2), (2, 2)] at 0x7fea152a9210>

# %%
bs = state_d.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_d.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_d.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_d.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_d2.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_d2.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_d2.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 491.6291913986206
# <NestedBlockState object, with base <BlockState object with 63 blocks (62 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea166dd050>, at 0x7fea101d1950>, and 10 levels of sizes [(2638, 62), (62, 20), (20, 10), (10, 5), (5, 4), (4, 3), (3, 3), (3, 3), (3, 2), (2, 2)] at 0x7fea101d1350>

# %%
bs = state_d.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_d.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_d.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_d.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_d3.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_d3.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_d3.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 692.4885656833649
# <NestedBlockState object, with base <BlockState object with 65 blocks (63 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea166dd050>, at 0x7fea152d16d0>, and 10 levels of sizes [(2638, 63), (63, 18), (18, 8), (8, 6), (6, 4), (4, 3), (3, 2), (2, 2), (2, 2), (2, 2)] at 0x7fea152d1990>

# %%
estate_d1=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_d1.pkl", "rb" ))
estate_d2=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_d2.pkl", "rb" ))
estate_d3=pickle.load( open( "pbmc/pbmc_reliability_test/e_state_d3.pkl", "rb" ))

# %% [markdown]
# ##### 2ae)  state_e (809)(525)(727) (11 min e 30 sec)

# %%
bs = state_e.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_e.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_e.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_e.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_e1.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_e1.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_e1.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 809.7820963859558
# <NestedBlockState object, with base <BlockState object with 94 blocks (92 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1537ae50>, at 0x7fea10123d10>, and 10 levels of sizes [(2638, 92), (92, 22), (22, 11), (11, 6), (6, 4), (4, 4), (4, 3), (3, 2), (2, 2), (2, 1)] at 0x7fea101235d0>

# %%
bs = state_e.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_e.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_e.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_e.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_e2.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_e2.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_e2.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 525.5276424884796
# <NestedBlockState object, with base <BlockState object with 93 blocks (91 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1537ae50>, at 0x7fea168f3ed0>, and 10 levels of sizes [(2638, 91), (91, 20), (20, 8), (8, 5), (5, 5), (5, 5), (5, 3), (3, 3), (3, 2), (2, 2)] at 0x7fea168f3a90>

# %%
bs = state_e.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_e.copy(bs=bs, sampling=True)
gt.mcmc_equilibrate(state, wait=10, mcmc_args=dict(niter=10))
h = [np.zeros(g.num_vertices() + 1) for s in state.get_levels()]
pv = [None] * len(state.get_levels())


def collect_info(s):
    for l,sl in enumerate(s.get_levels()):
        B=sl.get_nonempty_B()
        h[l][B] +=1
        global pv
        pv=[sl.collect_vertex_marginals(pv[l]) for l, sl in enumerate(s.get_levels())]

# %%
bs = state_e.get_bs()                   
bs += [np.zeros(1)] * (10 - len(bs))

state = state_e.copy(bs=bs, sampling=True)

a=time.time()
gt.mcmc_equilibrate(state, wait=1000,nbreaks=2, max_niter=10000,epsilon=0.001, mcmc_args=dict(niter=10),callback=collect_info)
b=time.time()
pickle.dump(state,open("pbmc/pbmc_reliability_test/e_state_e3.pkl",'wb'),2)
pickle.dump(h,open("pbmc/pbmc_weighted_vs_normal/h_e3.pkl",'wb'),2)
pickle.dump(pv,open("pbmc/pbmc_weighted_vs_normal/pv_e3.pkl",'wb'),2)
c=b-a
print(c)

state
# Out:
# 727.9552972316742
# <NestedBlockState object, with base <BlockState object with 95 blocks (94 nonempty), for graph <Graph object, undirected, with 2638 vertices and 20976 edges at 0x7fea1537ae50>, at 0x7fea1020c6d0>, and 10 levels of sizes [(2638, 94), (94, 22), (22, 10), (10, 5), (5, 4), (4, 4), (4, 4), (4, 2), (2, 1), (1, 1)] at 0x7fea1020c8d0>

# %%
estate_e1=pickle.load( open( "pbmc/pbmc_reliability_test/e_state